# %% [markdown]
# # **Project Name**    - **AMAZON  PRIME TV SHOWS and MOVIES(EDA)**

# %% [markdown]
# ##### **Project Type**  - EDA
# ##### **Contribution**  - Individual
# #####  NAME - Saniya kousar

# %% [markdown]
# # **Project Summary -**

# %% [markdown]
# The **Amazon TV Shows and Movies Exploratory Data Analysis (EDA)** project focuses on analyzing a dataset of movies and TV shows available on the Amazon platform. The main objective of this project is to explore the dataset, identify meaningful patterns and trends, understand the characteristics of available content, and generate useful insights through data analysis and visualization. This project helped in understanding how real-world entertainment data can be cleaned, explored, and interpreted using Python and popular data analysis libraries.
#
# The project started with **data collection and understanding the dataset structure**. The dataset contains information about different movies and TV shows, including attributes such as title, type, release year, rating, duration, genre, country, date added, and other relevant details. The dataset was initially examined using Python to understand the number of rows and columns, data types, missing values, and duplicate records. Basic statistical analysis was also performed to understand the numerical features and their distributions.
#
# The next stage involved **data cleaning and preprocessing**. Missing values were identified and handled appropriately depending on the column and the importance of the information. Duplicate records were checked and removed where necessary. Columns containing dates and numerical values were converted into suitable data types to make further analysis easier. Inconsistent or unnecessary data was also reviewed to improve the quality and reliability of the dataset before performing detailed analysis.
#
# The major part of the project involved **exploratory data analysis**. Different questions were explored to understand the content available on Amazon. The analysis compared the number of **movies and TV shows** and examined how content availability changed over different years. The distribution of content based on ratings was analyzed to identify the most common audience categories. The project also explored the most frequently occurring genres and countries producing Amazon content.
#
# Additional analysis was performed on **release years and content duration** to understand how the platform's catalog has developed over time. Visualization techniques such as bar charts, count plots, histograms, pie charts, and line graphs were used to represent the findings clearly. These visualizations made it easier to identify trends and compare different categories of content.
#
# The project also examined **popular genres, ratings, countries, and yearly content additions** to derive meaningful insights. For example, the analysis can help identify whether the platform has more movies or TV shows, which genres are most common, which ratings dominate the catalog, and how the amount of content has changed over the years. Such insights demonstrate how EDA can be used to transform raw entertainment data into understandable information.
#
# The project was implemented using **Python**, primarily with libraries such as **Pandas, NumPy, Matplotlib, and Seaborn**. Pandas was used for data manipulation and cleaning, NumPy for numerical operations, and Matplotlib and Seaborn for data visualization. Jupyter Notebook was used to perform the analysis interactively and document the results.
#
# Overall, this project provided practical experience in **data cleaning, data preprocessing, exploratory analysis, visualization, and insight generation**. It improved understanding of how to work with real-world datasets and how to communicate analytical findings using visualizations. The Amazon TV Shows and Movies EDA project demonstrates the ability to analyze a dataset systematically and extract useful business and content-related insights from raw data.

# %% [markdown]
# ![amazon img.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# # **GitHub Link -**

# %% [markdown]
# https://github.com/saniyakauser1926/Amazon-Prime-TV-Shows-and-Movies-EDA-

# %% [markdown]
# # **Problem Statement**

# %% [markdown]
# This project analyzes the Amazon Prime Video dataset to extract meaningful insights about the content available on the platform.
#
# The analysis focuses on:
#
# Content Diversity: Which genres and categories dominate the platform?
# Regional Availability: How does content distribution vary across different regions?
# Trends Over Time: How has Amazon Prime Video's content library evolved?
# IMDb Ratings & Popularity: Which shows or movies have the highest ratings and popularity?
#
# Using Pandas, NumPy, Matplotlib, and Seaborn, the dataset will be cleaned, explored, and visualized to identify important patterns and trends.

# %% [markdown]
# #### **Define Your Business Objective?**

# %% [markdown]
# The business objective of this project is to analyze Amazon Prime Video's movies and TV shows dataset to identify content trends, audience preferences, regional availability, and rating patterns. These insights can help Amazon make better decisions about content acquisition, production, regional expansion, and customer engagement.

# %% [markdown]
# # ***Let's Begin !***

# %% [markdown]
# ## ***1. Know Your Data***

# %% [markdown]
# ### Import Libraries

# %%
# Import Libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
title_df = pd.read_csv('/content/titles.csv')
display(title_df.head())
# Out:
#         id                        title   type  \
# 0  ts20945            The Three Stooges   SHOW
# 1  tm19248                  The General  MOVIE
# 2  tm82253  The Best Years of Our Lives  MOVIE
# 3  tm83884              His Girl Friday  MOVIE
# 4  tm56584            In a Lonely Place  MOVIE
#
#                                          description  release_year  \
# 0  The Three Stooges were an American vaudeville ...          1934
# 1  During America’s Civil War, Union spies steal ...          1926
# 2  It's the hope that sustains the spirit of ever...          1946
# 3  Hildy, the journalist former wife of newspaper...          1940
# 4  An aspiring actress begins to suspect that her...          1950
#
#   age_certification  runtime  \
# 0             TV-PG       19
# 1               NaN       78
# 2               NaN      171
# 3               NaN       92
# 4               NaN       94
#
#                                               genres production_countries  \
# ...

# %%
credit_df = pd.read_csv('/content/credits.csv')
display(credit_df.head())
# Out:
#    person_id       id           name      character   role
# 0      59401  ts20945     Joe Besser            Joe  ACTOR
# 1      31460  ts20945     Moe Howard            Moe  ACTOR
# 2      31461  ts20945     Larry Fine          Larry  ACTOR
# 3      21174  tm19248  Buster Keaton    Johnny Gray  ACTOR
# 4      28713  tm19248    Marion Mack  Annabelle Lee  ACTOR

# %% [markdown]
# ### Dataset Loading

# %% [markdown]
# # Load Dataset
# title_df = pd.read_csv('/content/titles.csv')

# %%
title_df = pd.read_csv('/content/titles.csv')
display(title_df.head())
# Out:
#         id                        title   type  \
# 0  ts20945            The Three Stooges   SHOW
# 1  tm19248                  The General  MOVIE
# 2  tm82253  The Best Years of Our Lives  MOVIE
# 3  tm83884              His Girl Friday  MOVIE
# 4  tm56584            In a Lonely Place  MOVIE
#
#                                          description  release_year  \
# 0  The Three Stooges were an American vaudeville ...          1934
# 1  During America’s Civil War, Union spies steal ...          1926
# 2  It's the hope that sustains the spirit of ever...          1946
# 3  Hildy, the journalist former wife of newspaper...          1940
# 4  An aspiring actress begins to suspect that her...          1950
#
#   age_certification  runtime  \
# 0             TV-PG       19
# 1               NaN       78
# 2               NaN      171
# 3               NaN       92
# 4               NaN       94
#
#                                               genres production_countries  \
# ...

# %%
credit_df = pd.read_csv('/content/credits.csv')

# %% [markdown]
# ### Dataset First View

# %%
# Dataset First Look
title_df.head()
# Out:
#         id                        title   type  \
# 0  ts20945            The Three Stooges   SHOW
# 1  tm19248                  The General  MOVIE
# 2  tm82253  The Best Years of Our Lives  MOVIE
# 3  tm83884              His Girl Friday  MOVIE
# 4  tm56584            In a Lonely Place  MOVIE
#
#                                          description  release_year  \
# 0  The Three Stooges were an American vaudeville ...          1934
# 1  During America’s Civil War, Union spies steal ...          1926
# 2  It's the hope that sustains the spirit of ever...          1946
# 3  Hildy, the journalist former wife of newspaper...          1940
# 4  An aspiring actress begins to suspect that her...          1950
#
#   age_certification  runtime  \
# 0             TV-PG       19
# 1               NaN       78
# 2               NaN      171
# 3               NaN       92
# 4               NaN       94
#
#                                               genres production_countries  \
# ...

# %%
credit_df.head()
# Out:
#    person_id       id           name      character   role
# 0      59401  ts20945     Joe Besser            Joe  ACTOR
# 1      31460  ts20945     Moe Howard            Moe  ACTOR
# 2      31461  ts20945     Larry Fine          Larry  ACTOR
# 3      21174  tm19248  Buster Keaton    Johnny Gray  ACTOR
# 4      28713  tm19248    Marion Mack  Annabelle Lee  ACTOR

# %% [markdown]
# ### Dataset Rows & Columns count

# %%
# Dataset Rows & Columns count
title_df.shape
# Out:
# (9871, 15)

# %%
credit_df.shape
# Out:
# (124235, 5)

# %% [markdown]
# ### Dataset Information

# %%
# Dataset Info
title_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9871 entries, 0 to 9870
# Data columns (total 15 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   id                    9871 non-null   object
#  1   title                 9871 non-null   object
#  2   type                  9871 non-null   object
#  3   description           9752 non-null   object
#  4   release_year          9871 non-null   int64
#  5   age_certification     3384 non-null   object
#  6   runtime               9871 non-null   int64
#  7   genres                9871 non-null   object
#  8   production_countries  9871 non-null   object
#  9   seasons               1357 non-null   float64
#  10  imdb_id               9204 non-null   object
#  11  imdb_score            8850 non-null   float64
#  12  imdb_votes            8840 non-null   float64
#  13  tmdb_popularity       9324 non-null   float64
#  14  tmdb_score            7789 non-null   float64
# ...

# %%
credit_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 124235 entries, 0 to 124234
# Data columns (total 5 columns):
#  #   Column     Non-Null Count   Dtype
# ---  ------     --------------   -----
#  0   person_id  124235 non-null  int64
#  1   id         124235 non-null  object
#  2   name       124235 non-null  object
#  3   character  107948 non-null  object
#  4   role       124235 non-null  object
# dtypes: int64(1), object(4)
# memory usage: 4.7+ MB

# %% [markdown]
# #### Duplicate Values

# %%
# Dataset Duplicate Value Count
title_df.duplicated().sum()
# Out:
# np.int64(3)

# %%
credit_df.duplicated().sum()
# Out:
# np.int64(56)

# %% [markdown]
# #### Missing Values/Null Values

# %%
# Missing Values/Null Values Count
title_df.isnull().sum()
# Out:
# id                         0
# title                      0
# type                       0
# description              119
# release_year               0
# age_certification       6487
# runtime                    0
# genres                     0
# production_countries       0
# seasons                 8514
# imdb_id                  667
# imdb_score              1021
# imdb_votes              1031
# tmdb_popularity          547
# tmdb_score              2082
# dtype: int64

# %% [markdown]
# ## ***2. Understanding Your Variables***

# %%
# Dataset Columns
title_df.columns
# Out:
# Index(['id', 'title', 'type', 'description', 'release_year',
#        'age_certification', 'runtime', 'genres', 'production_countries',
#        'seasons', 'imdb_id', 'imdb_score', 'imdb_votes', 'tmdb_popularity',
#        'tmdb_score'],
#       dtype='object')

# %%
# Dataset Describe
credit_df.columns
# Out:
# Index(['person_id', 'id', 'name', 'character', 'role'], dtype='object')

# %%
#dataset describe
title_df.describe()
# Out:
#        release_year      runtime      seasons   imdb_score    imdb_votes  \
# count   9871.000000  9871.000000  1357.000000  8850.000000  8.840000e+03
# mean    2001.327221    85.973052     2.791452     5.976395  8.533614e+03
# std       25.810071    33.512466     4.148958     1.343842  4.592015e+04
# min     1912.000000     1.000000     1.000000     1.100000  5.000000e+00
# 25%     1995.500000    65.000000     1.000000     5.100000  1.170000e+02
# 50%     2014.000000    89.000000     1.000000     6.100000  4.625000e+02
# 75%     2018.000000   102.000000     3.000000     6.900000  2.236250e+03
# max     2022.000000   549.000000    51.000000     9.900000  1.133692e+06
#
#        tmdb_popularity   tmdb_score
# count      9324.000000  7789.000000
# mean          6.910204     5.984247
# std          30.004098     1.517986
# min           0.000011     0.800000
# 25%           1.232000     5.100000
# 50%           2.536000     6.000000
# 75%           5.634000     6.900000
# ...

# %%
credit_df.describe()
# Out:
#           person_id
# count  1.242350e+05
# mean   4.064737e+05
# std    5.616296e+05
# min    1.000000e+00
# 25%    3.899200e+04
# 50%    1.339490e+05
# 75%    5.712560e+05
# max    2.371153e+06

# %% [markdown]
# ### Variables Description

# %% [markdown]
# **Variable Description:**
#
# show_id - Unique identification number for each content.
#
# type – Specifies whether the content is a Movie or TV Show.
#
# title – Name of the movie or TV show.
#
# director – Name of the director.
#
# cast – Names of actors/actresses.
#
# country – Country where the content was produced.

# %% [markdown]
# ### Check Unique Values for each variable.

# %%
# Check Unique Values for each variable.
title_df.nunique()
# Out:
# id                      9868
# title                   9737
# type                       2
# description             9734
# release_year             110
# age_certification         11
# runtime                  207
# genres                  2028
# production_countries     497
# seasons                   32
# imdb_id                 9201
# imdb_score                86
# imdb_votes              3650
# tmdb_popularity         5325
# tmdb_score                89
# dtype: int64

# %%
credit_df.nunique()
# Out:
# person_id    80508
# id            8861
# name         79758
# character    71097
# role             2
# dtype: int64

# %% [markdown]
# ## 3. ***Data Wrangling***

# %% [markdown]
# ### Data Wrangling Code

# %%
# Replacing NaN values with "Not Rated" in the age_certification column
title_df['age_certification'] = title_df['age_certification'].fillna('Not Rated')

# Filling null values with mean values in imdb_score column
title_df['imdb_score'].fillna(title_df['imdb_score'].mean(), inplace=True)

# Dropping duplicate values for both title_df and credit_df
title_df.drop_duplicates(inplace=True)
credit_df.drop_duplicates(inplace=True)

# Merging title_df dataset and credit_df dataset using 'id' as primary key
merged_df = title_df.merge(credit_df, on='id', how='left')

# Creating a column for decade
title_df['decade'] = (title_df['release_year'] // 10) * 10

# Categorize runtime into short, medium, long
merged_df['runtime_category'] = ''
for i in range(len(merged_df)):
    if merged_df.loc[i, 'runtime'] < 30:
        merged_df.loc[i, 'runtime_category'] = 'Short'
    elif merged_df.loc[i, 'runtime'] <= 90:
        merged_df.loc[i, 'runtime_category'] = 'Medium'
    else:
        merged_df.loc[i, 'runtime_category'] = 'Long'

# Add column is_movie (1 if movie, 0 if show)
merged_df['is_movie'] = 0
for i in range(len(merged_df)):
    if merged_df.loc[i, 'type'] == 'MOVIE':
        merged_df.loc[i, 'is_movie'] = 1
    else:
        merged_df.loc[i, 'is_movie'] = 0
# Out:
# /tmp/ipykernel_5013/3466015820.py:5: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   title_df['imdb_score'].fillna(title_df['imdb_score'].mean(), inplace=True)

# %%
for i in range(len(merged_df)):
    score = merged_df.loc[i, 'imdb_score']

    if pd.isna(score):
        merged_df.loc[i, 'rating_category'] = 'not rated'

    elif score < 5:
        merged_df.loc[i, 'rating_category'] = 'poor'

    elif score < 7:
        merged_df.loc[i, 'rating_category'] = 'average'

    elif score < 8.5:
        merged_df.loc[i, 'rating_category'] = 'good'

    else:
        merged_df.loc[i, 'rating_category'] = 'excellent'

# %% [markdown]
# ### What all manipulations have you done and insights you found?

# %% [markdown]
# I cleaned the data by handling missing values and duplicates, correcting data types, and performing filtering, grouping, and visualization. I found insights about popular genres, content types, ratings, countries, and yearly content trends.

# %% [markdown]
# **BOXPLOT**

# %% [markdown]
# BOX PLOT
# the boxplot are plotted to visualise the distribution, spread of data and to identify the outliersin the data

# %%
plt.figure(figsize=(8,6))
sns.boxplot(data=title_df, y='imdb_score')
plt.title('box plot of imdb_score\n', color = 'brown')
plt.show()

# %% [markdown]
# INSIGHTS
#
# 1. Most content has an **IMDb score between 5.3 and 6.8**, with a **median around 6.0** — indicating the majority of titles are moderately rated rather than extremely high or low.
# 2. There are **outliers on both ends** — a cluster of titles scoring **above 9** (highly rated gems) and a cluster scoring **below 3** (poorly rated content).

# %%
#Blox plot for runtime
plt.figure(figsize=(8,6))
sns.boxplot(data=title_df, x='runtime')
plt.title('box plot of runtime\n', color = 'brown')
plt.show()

# %% [markdown]
# INSIGHTS
#
# 1. Most content has a **runtime between roughly 70–100 minutes**, with the **median around 90 minutes** — typical of standard movie lengths.
# 2. There are **many outliers on the higher end**, with runtimes extending up to **500+ minutes** — these are likely TV shows or mini-series where "runtime" reflects total/season length rather than a single episode.

# %% [markdown]
# HISTOGRAM
#
#
# it represents the distribution of numerical variable. they provide a visual way to see the shape of data  distribution

# %% [markdown]
# ## ***4. Data Vizualization, Storytelling & Experimenting with charts : Understand the relationships between variables***

# %% [markdown]
# Chart - 1 Movie vs TV shows

# %%
#Movies vs TV shows
merged_df['type'].value_counts().plot(kind='bar', color = ['skyblue','orange'])
plt.title('movies vs shows on amazon prime')
plt.xlabel('type')
plt.ylabel('count')
plt.show()

# %% [markdown]
# 1. Why did you pick the specific chart?

# %% [markdown]
# I selected a bar chart because I wanted to compare values across different categories. It makes the differences between categories clearly visible and helps the user quickly identify the highest and lowest values.

# %% [markdown]
#  2.What is/are the insight(s) found from the chart?

# %% [markdown]
# The chart shows how the number of titles has changed over the years. We can identify the years with higher and lower content additions and understand the growth trend of the content library.

# %% [markdown]
# 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Positive growth :
#
# Yes. This insight helps Amazon understand whether customers have more movie or TV show content available. It can help maintain a better balance of content.
#
#
# Negative growth:
#
# If one type of content is much lower, it may reduce choices for customers and affect customer satisfaction.

# %% [markdown]
# #### Chart - 2  Release by year

# %%
merged_df['release_year'].value_counts().sort_index().plot(kind = 'line',color = 'green')
plt.title('content released for year')
plt.xlabel('release year')
plt.ylabel('number of titles')
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# I selected a line chart because I wanted to show how the values change over time. It clearly displays the trend and makes increases, decreases, and fluctuations easy to identify.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# The chart shows how the number of titles has changed over the years. We can identify the years with higher and lower content additions and understand the growth trend of the content library.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Positive business impact:
#
# Yes. This helps Amazon understand how its content library is growing over time and plan future content additions.
#
#
# Negative growth:
#
# If content additions decrease in recent years, it may indicate slower content growth and could reduce customer interest.

# %% [markdown]
# #### Chart - 3    Runtime Distribution

# %%
# Runtime Distribution

plt.hist(merged_df['runtime'].dropna(), bins=30, color='purple', edgecolor='black')

plt.title('Distribution of Movie Runtimes')
plt.xlabel('Runtime (minutes)')
plt.ylabel('Count')

plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# I selected a bar chart because I wanted to compare values across different categories. It makes the differences between categories clearly visible and helps the user quickly identify the highest and lowest values.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# The chart shows the distribution of content based on runtime. Most titles are concentrated around the common runtime range, while some longer titles appear as outliers.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Positive business impact:
#
# Yes. It helps Amazon understand the common duration of movies and shows and plan content according to audience preferences.
#
#
# Negative growth:
#
# Too much very long or very short content may not satisfy all viewers and could reduce engagement.

# %% [markdown]
# #### Chart - 4  TOP 10 GENERS BY COUNT

# %%
import ast
title_df['genres'] = title_df['genres'].apply(ast.literal_eval)
genres_split = title_df.explode('genres')

genres_split['genres'].value_counts().head(10).plot(kind='bar', color='pink')
plt.title('Top 10 Genres by Count')
plt.xlabel('Genre')
plt.ylabel('Number of Titles')
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# I selected a bar chart because I wanted to compare values across different categories. It makes the differences between categories clearly visible and helps the user quickly identify the highest and lowest values.”

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# The chart shows the most common genres on Amazon Prime. The highest-count genres indicate the types of content that are more widely represented in the catalog. This can help Amazon understand content preferences and plan future content.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Positive business impact:
#
# Yes. Amazon can identify popular genres and invest more in those types of content to attract and retain customers.
#
#
# Negative growth:
#
# If Amazon focuses too much on only a few genres, the content library may become less diverse and some customers may lose interest.

# %% [markdown]
# #### Chart - 5   Geners Vs IMDB Heatmap

# %%
genres_pivot = genres_split.pivot_table(index='genres', values='imdb_score', aggfunc='mean').sort_values('imdb_score', ascending=False).head(15)
sns.heatmap(genres_pivot, annot=True, cmap="Blues")
plt.title('Average IMDB Rating by Genres')
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# A heatmap shows numeric values as colors in a grid darker/lighter shades represent higher/lower values, making patterns easy to spot at a glance instead of reading numbers one by one.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# The heatmap shows the average IMDb rating for different genres. We can identify which genres have relatively higher or lower average ratings. This can help Amazon understand which types of content are associated with better audience ratings.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Positive business impact:
#
# Yes. Amazon can identify genres with higher average ratings and focus on producing or acquiring quality content in those genres.
#
#
# Negative growth:
#
# Genres with lower ratings may indicate that some content is not performing well and could lead to lower customer satisfaction.

# %% [markdown]
# #### Chart - 6 Role Distribution

# %%
# Creating role_dist first
role_dist = credit_df['role'].value_counts()

# Then plot it
role_dist.plot(kind='pie', autopct='%1.1f%%', startangle=90, colors=['gold', 'lightcoral', 'blue'])
plt.title('Role Distribution (Actor, Director, Writer)')
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# > I selected a pie chart because I wanted to show how different categories contribute to the total. It makes the proportion or percentage of each category easy to understand.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# The chart shows the distribution of roles such as actors, directors and writers. It helps us understand how the credits are distributed across different roles.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Positive business impact:
#
# Yes. This helps Amazon understand the contribution of actors, directors and writers and identify important talent areas.
#
#
# Negative growth:
#
# If there is less variety in talent, it may limit content quality and creativity.

# %% [markdown]
# #### Chart - 7   TOP 10 PRODUCTION COUNTRIES

# %%
import ast
title_df['production_countries'] = title_df['production_countries'].apply(ast.literal_eval)
countries_split = title_df.explode('production_countries')
top_countries = countries_split['production_countries'].value_counts().head(10)
top_countries.plot(kind='bar', color='blue')
plt.title('Top 10 Production Countries')
plt.xlabel('Country')
plt.ylabel('Count')
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# I selected a bar chart because I wanted to compare values across different categories. It makes the differences between categories clearly visible and helps the user quickly identify the highest and lowest values.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# The chart identifies the top countries producing content available on Amazon Prime. This gives insight into the regional distribution of the content and can help Amazon identify important content-producing markets

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Positive business impact:
#
# Yes. Amazon can identify major content-producing countries and invest in regional content and expansion.
#
#
#
#
# Negative growth:
#
# If content is concentrated in only a few countries, Amazon may have less regional diversity and may not meet the preferences of customers from other regions.

# %% [markdown]
# #### Chart - 8 - Top 10 popular Titles

# %%
top_popular = title_df.nlargest(10, 'tmdb_popularity')
sns.boxplot(data=top_popular, x = 'tmdb_popularity' , hue ='title', palette = 'mako')
plt.title('Top 10 most popular titles on amazon Prime')
plt.xlabel('TMDB Popularity score')
plt.ylabel('title')
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# We use this chart because it's the simplest, clearest way to rank and compare popularity scores across multiple titles — turning raw numbers into an easy visual story.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# The chart identifies the top 10 titles based on TMDB popularity. These titles represent highly popular content and can help Amazon understand which content attracts more audience interest.

# %% [markdown]
# 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Yes. Amazon can understand which titles are attracting more audience interest and use this information for recommendations and future content planning.
#
# Negative growth:
#
# If only a small number of titles are highly popular, Amazon may become dependent on those titles. If their popularity decreases, customer engagement may also decrease.

# %% [markdown]
# ## **5. Solution to Business Objective**

# %% [markdown]
# #### What do you suggest the client to achieve Business Objective ?

# %% [markdown]
# Based on my EDA, I suggest Amazon Prime focus on popular genres and countries, invest in high-performing content and talent, maintain a good balance between movies and TV shows, regularly add new content, and use customer preferences to improve personalized recommendations. These actions can help increase customer engagement and retention.”

# %% [markdown]
# # **Conclusion**

# %% [markdown]
# ### Conclusion
#
# The Amazon Prime Video EDA helped us understand the available movies and TV shows. We found useful patterns in genres, countries, ratings, and popularity. These insights can help Amazon improve its content, recommendations, and customer engagement.

# %% [markdown]
# ### ***Hurrah! You have successfully completed your EDA Capstone Project !!!***
